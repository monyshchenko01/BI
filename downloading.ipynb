# %%
# !pip install gdown requests

# %%
import os
import gdown

folder_url = "https://drive.google.com/drive/folders/1NNq2d7KRzZ7f937q9Clrmk0uCvo-lzyf"
output_dir = "data"

os.makedirs(output_dir, exist_ok=True)

gdown.download_folder(url=folder_url, output=output_dir, quiet=False, use_cookies=False)
# Out:
# Retrieving folder contents
# Processing file 1a8q_S0gvbIYEakMgdpjj-COxMPEufg2u final_hits_10.csv
# Processing file 1GMzydddCrAEIEXVJ_JMAWBxQz_lrRkKB final_products_10.csv
# Processing file 1vvLG65ZFkSe8NCbOKN8yGVJ5uXUYZZFV final_sessions_10.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1a8q_S0gvbIYEakMgdpjj-COxMPEufg2u
# To: /Users/oleksandrsiryi/PycharmProjects/BI/data/final_hits_10.csv
# 100%|██████████| 26.2M/26.2M [00:08<00:00, 3.12MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1GMzydddCrAEIEXVJ_JMAWBxQz_lrRkKB
# To: /Users/oleksandrsiryi/PycharmProjects/BI/data/final_products_10.csv
# 100%|██████████| 6.39M/6.39M [00:01<00:00, 3.91MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1vvLG65ZFkSe8NCbOKN8yGVJ5uXUYZZFV
# To: /Users/oleksandrsiryi/PycharmProjects/BI/data/final_sessions_10.csv
# 100%|██████████| 4.95M/4.95M [00:03<00:00, 1.55MB/s]
# Download completed
# ['data/final_hits_10.csv',
#  'data/final_products_10.csv',
#  'data/final_sessions_10.csv']
